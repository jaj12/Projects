# %%
import pandapower as pp
import pandapower.plotting as plot
import pandas as pd
import warnings
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandapower as pp
#       2 import pandapower.plotting as plot
#       3 import pandas as pd
#
# File ~\PycharmProjects\energyinfo\venv\lib\site-packages\pandapower\__init__.py:17
#      15 from pandapower.groups import *
#      16 from pandapower.diagnostic import *
# ---> 17 from pandapower.runpm import *
#      18 from pandapower.pf.runpp_3ph import runpp_3ph
#      20 import pandas as pd
#
# File ~\PycharmProjects\energyinfo\venv\lib\site-packages\pandapower\runpm.py:8
#       6 import os
#       7 from pandapower.auxiliary import _add_ppc_options, _add_opf_options
# ----> 8 from pandapower.converter.pandamodels.from_pm import read_ots_results, read_tnep_results
#       9 from pandapower.opf.pm_storage import add_storage_opf_settings, read_pm_storage_results
#      10 from pandapower.opf.run_pandamodels import _runpm
#
# File ~\PycharmProjects\energyinfo\venv\lib\site-packages\pandapower\converter\__init__.py:4
#       2 from pandapower.converter.pypower import *
#       3 from pandapower.converter.pandamodels import *
# ----> 4 from pandapower.converter.cim import *
#       5 from pandapower.converter.powerfactory import *
#
# File ~\PycharmProjects\energyinfo\venv\lib\site-packages\pandapower\converter\cim\__init__.py:5
#       1 # -*- coding: utf-8 -*-
#       2
#       3 # Copyright (c) 2016-2023 by University of Kassel and Fraunhofer Institute for Energy Economics
#       4 # and Energy System Technology (IEE), Kassel. All rights reserved.
# ----> 5 from .cim2pp import from_cim
#       7 __version__ = '3.6.9'
#
# File ~\PycharmProjects\energyinfo\venv\lib\site-packages\pandapower\converter\cim\cim2pp\__init__.py:5
#       1 # -*- coding: utf-8 -*-
#       2
#       3 # Copyright (c) 2016-2023 by University of Kassel and Fraunhofer Institute for Energy Economics
#       4 # and Energy System Technology (IEE), Kassel. All rights reserved.
# ----> 5 from . import converter_classes
#
# File ~\PycharmProjects\energyinfo\venv\lib\site-packages\pandapower\converter\cim\cim2pp\converter_classes\__init__.py:1
# ----> 1 from . import connectivitynodes, coordinates, externalnetworks, generators, impedance, lines, loads, shunts, switches, transformers, wards
#
# File ~\PycharmProjects\energyinfo\venv\lib\site-packages\pandapower\converter\cim\cim2pp\converter_classes\connectivitynodes\__init__.py:1
# ----> 1 from . import connectivityNodesCim16
#
# File ~\PycharmProjects\energyinfo\venv\lib\site-packages\pandapower\converter\cim\cim2pp\converter_classes\connectivitynodes\connectivityNodesCim16.py:8
#       5 import pandas as pd
#       7 from pandapower.converter.cim import cim_tools
# ----> 8 from pandapower.converter.cim.cim2pp import build_pp_net
#       9 from pandapower.converter.cim.other_classes import Report, LogLevel, ReportCode
#      11 logger = logging.getLogger('cim.cim2pp.converter_classes.connectivityNodesCim16')
#
# File ~\PycharmProjects\energyinfo\venv\lib\site-packages\pandapower\converter\cim\cim2pp\build_pp_net.py:13
#      11 import pandapower as pp
#      12 import pandapower.auxiliary
# ---> 13 from .convert_measurements import CreateMeasurements
#      14 from .. import cim_classes
#      15 from .. import cim_tools
#
# File ~\PycharmProjects\energyinfo\venv\lib\site-packages\pandapower\converter\cim\cim2pp\convert_measurements.py:14
#      10 import pandapower.auxiliary
#      11 from .. import cim_tools
# ---> 14 class CreateMeasurements:
#      16     def __init__(self, net: pandapower.auxiliary.pandapowerNet, cim: Dict):
#      17         self.logger = logging.getLogger(self.__class__.__name__)
#
# File ~\PycharmProjects\energyinfo\venv\lib\site-packages\pandapower\converter\cim\cim2pp\convert_measurements.py:16, in CreateMeasurements()
#      14 class CreateMeasurements:
# ---> 16     def __init__(self, net: pandapower.auxiliary.pandapowerNet, cim: Dict):
#      17         self.logger = logging.getLogger(self.__class__.__name__)
#      18         self.net = net
#
# AttributeError: partially initialized module 'pandapower' has no attribute 'auxiliary' (most likely due to a circular import)

# %%
import pandapower as pp
import pandas as pd

print("Imports successful")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandapower as pp
#       2 import pandas as pd
#       4 print("Imports successful")
#
# File ~\PycharmProjects\energyinfo\venv\lib\site-packages\pandapower\__init__.py:17
#      15 from pandapower.groups import *
#      16 from pandapower.diagnostic import *
# ---> 17 from pandapower.runpm import *
#      18 from pandapower.pf.runpp_3ph import runpp_3ph
#      20 import pandas as pd
#
# File ~\PycharmProjects\energyinfo\venv\lib\site-packages\pandapower\runpm.py:8
#       6 import os
#       7 from pandapower.auxiliary import _add_ppc_options, _add_opf_options
# ----> 8 from pandapower.converter.pandamodels.from_pm import read_ots_results, read_tnep_results
#       9 from pandapower.opf.pm_storage import add_storage_opf_settings, read_pm_storage_results
#      10 from pandapower.opf.run_pandamodels import _runpm
#
# File ~\PycharmProjects\energyinfo\venv\lib\site-packages\pandapower\converter\pandamodels\from_pm.py:12
#      10 from copy import deepcopy
#      11 from pandapower.auxiliary import _clean_up
# ---> 12 from pandapower.converter import logger
#      13 from pandapower.pypower.idx_brch import PF, PT, QF, QT, BR_STATUS
#      14 from pandapower.pypower.idx_bus import VA, VM
#
# File ~\PycharmProjects\energyinfo\venv\lib\site-packages\pandapower\converter\__init__.py:4
#       2 from pandapower.converter.pypower import *
#       3 from pandapower.converter.pandamodels import *
# ----> 4 from pandapower.converter.cim import *
#       5 from pandapower.converter.powerfactory import *
#
# File ~\PycharmProjects\energyinfo\venv\lib\site-packages\pandapower\converter\cim\__init__.py:5
#       1 # -*- coding: utf-8 -*-
#       2
#       3 # Copyright (c) 2016-2023 by University of Kassel and Fraunhofer Institute for Energy Economics
#       4 # and Energy System Technology (IEE), Kassel. All rights reserved.
# ----> 5 from .cim2pp import from_cim
#       7 __version__ = '3.6.9'
#
# File ~\PycharmProjects\energyinfo\venv\lib\site-packages\pandapower\converter\cim\cim2pp\__init__.py:5
#       1 # -*- coding: utf-8 -*-
#       2
#       3 # Copyright (c) 2016-2023 by University of Kassel and Fraunhofer Institute for Energy Economics
#       4 # and Energy System Technology (IEE), Kassel. All rights reserved.
# ----> 5 from . import converter_classes
#
# File ~\PycharmProjects\energyinfo\venv\lib\site-packages\pandapower\converter\cim\cim2pp\converter_classes\__init__.py:1
# ----> 1 from . import connectivitynodes, coordinates, externalnetworks, generators, impedance, lines, loads, shunts, switches, transformers, wards
#
# File ~\PycharmProjects\energyinfo\venv\lib\site-packages\pandapower\converter\cim\cim2pp\converter_classes\connectivitynodes\__init__.py:1
# ----> 1 from . import connectivityNodesCim16
#
# File ~\PycharmProjects\energyinfo\venv\lib\site-packages\pandapower\converter\cim\cim2pp\converter_classes\connectivitynodes\connectivityNodesCim16.py:8
#       5 import pandas as pd
#       7 from pandapower.converter.cim import cim_tools
# ----> 8 from pandapower.converter.cim.cim2pp import build_pp_net
#       9 from pandapower.converter.cim.other_classes import Report, LogLevel, ReportCode
#      11 logger = logging.getLogger('cim.cim2pp.converter_classes.connectivityNodesCim16')
#
# File ~\PycharmProjects\energyinfo\venv\lib\site-packages\pandapower\converter\cim\cim2pp\build_pp_net.py:13
#      11 import pandapower as pp
#      12 import pandapower.auxiliary
# ---> 13 from .convert_measurements import CreateMeasurements
#      14 from .. import cim_classes
#      15 from .. import cim_tools
#
# File ~\PycharmProjects\energyinfo\venv\lib\site-packages\pandapower\converter\cim\cim2pp\convert_measurements.py:14
#      10 import pandapower.auxiliary
#      11 from .. import cim_tools
# ---> 14 class CreateMeasurements:
#      16     def __init__(self, net: pandapower.auxiliary.pandapowerNet, cim: Dict):
#      17         self.logger = logging.getLogger(self.__class__.__name__)
#
# File ~\PycharmProjects\energyinfo\venv\lib\site-packages\pandapower\converter\cim\cim2pp\convert_measurements.py:16, in CreateMeasurements()
#      14 class CreateMeasurements:
# ---> 16     def __init__(self, net: pandapower.auxiliary.pandapowerNet, cim: Dict):
#      17         self.logger = logging.getLogger(self.__class__.__name__)
#      18         self.net = net
#
# AttributeError: partially initialized module 'pandapower' has no attribute 'auxiliary' (most likely due to a circular import)
