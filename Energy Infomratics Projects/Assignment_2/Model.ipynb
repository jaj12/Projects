# %%
import pandapower as pp
import pandapower.plotting as plot
import pandas as pd
import warnings

# %% [markdown]
# Use pandapower
# acceleration service with all dependencies. (we will probably run a lot of iterations)
# each node has 1 generaiton and 1 node
